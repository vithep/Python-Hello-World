# %%
import random as r
from time import sleep

# %%
n=int(input("Digite um numero de 0 a 5: "))
comp=r.randint(0,5)
print('Processando....')
print('-'*12)
sleep(3)
if comp == n:
    print("Parabens você ganhou!!")
else:
    print('Tente novamente')
# Out:
# Digite um numero de 0 a 5: 4
# Processando....
# ------------
# Parabens você ganhou!!

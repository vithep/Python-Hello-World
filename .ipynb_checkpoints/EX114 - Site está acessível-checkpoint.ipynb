# %%
import urllib
import urllib.request

# %%
try:
    site = urllib.request.urlopen('http://www.google.com.br')
except urllib.error.URLError:
    print('Deu erro')
else:
    print('Tudo OK')
    print(site.read())
# Out:
# Tudo OK
# ...
